# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("lainguyn123/student-performance-factors")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'student-performance-factors' dataset.
# Path to dataset files: /kaggle/input/student-performance-factors

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/GSMADESH06/1.-SETTING-UP-THE-ENVIRONMENT-AND-PREPROCESSING-DATA-FOR-ML-APPLICATIONS-/refs/heads/main/student_performance_updated_1000.csv")
print("Original Dataset:")
print(df)
# Out:
# Original Dataset:
#      StudentID            Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1.0            John    Male            85.0               15.0
# 1          2.0           Sarah  Female            90.0               20.0
# 2          3.0            Alex    Male            78.0               10.0
# 3          4.0         Michael    Male            92.0               25.0
# 4          5.0            Emma  Female             NaN               18.0
# ..         ...             ...     ...             ...                ...
# 995        NaN  Kenneth Murray    Male            85.0               20.0
# 996     4497.0       Amy Stout  Female            91.0                NaN
# 997     1886.0             NaN    Male            85.0                8.0
# 998     7636.0  Joseph Sherman    Male            88.0               17.0
# 999     8021.0     Maria Walls  Female            88.0               10.0
#
#      PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade  \
# 0             78.0                        1.0            High        80.0
# 1             85.0                        2.0          Medium        87.0
# 2             65.0                        0.0             Low        68.0
# 3             90.0                        3.0            High        92.0
# 4             82.0                        2.0          Medium        85.0
# ..             ...                        ...             ...         ...
# 995            NaN                        1.0            High        72.0
# 996           86.0                        0.0            High        90.0
# 997           82.0                        2.0             Low        68.0
# 998           60.0                        2.0            High        85.0
# 999           90.0                        1.0          Medium         NaN
#
#      Study Hours  Attendance (%) Online Classes Taken
# 0            4.8            59.0                False
# 1            2.2            70.0                 True
# 2            4.6            92.0                False
# 3            2.9            96.0                False
# 4            4.1            97.0                 True
# ..           ...             ...                  ...
# 995          0.8            80.0                 True
# 996          3.9            80.0                 True
# 997          0.4            54.0                False
# 998          0.9            53.0                 True
# 999          2.4            94.0                 True
#
# [1000 rows x 12 columns]

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

# %%
display(df.describe())
# Out:
#          StudentID  AttendanceRate  StudyHoursPerWeek  PreviousGrade  \
# count  1000.000000     1000.000000        1000.000000    1000.000000
# mean   5416.019792       85.510417          17.630526      77.598759
# std    2600.077491        7.183836           6.113157       9.839977
# min       1.000000       70.000000           8.000000      60.000000
# 25%    3246.750000       82.000000          12.000000      70.000000
# 50%    5416.019792       85.510417          17.630526      78.000000
# 75%    7667.500000       91.000000          22.000000      86.000000
# max    9998.000000       95.000000          30.000000      90.000000
#
#        ExtracurricularActivities   FinalGrade  Study Hours  Attendance (%)
# count                1000.000000  1000.000000  1000.000000     1000.000000
# mean                    1.520376    80.030208     2.406967       77.248175
# std                     1.023670     9.301647     1.600686       18.897991
# min                     0.000000    62.000000    -5.000000       50.000000
# 25%                     1.000000    72.000000     1.200000       64.000000
# 50%                     1.520376    80.030208     2.453484       77.000000
# 75%                     2.000000    88.000000     3.700000       89.000000
# max                     3.000000    92.000000     5.000000      200.000000

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for column in df.select_dtypes(include='object').columns:
    df[column] = le.fit_transform(df[column])


print("\nDataset After Preprocessing and Label Encoding:")
print(df)
# Out:
# Dataset After Preprocessing and Label Encoding:
#        StudentID  Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0       1.000000   427       1       85.000000          15.000000
# 1       2.000000   826       0       90.000000          20.000000
# 2       3.000000    12       1       78.000000          10.000000
# 3       4.000000   646       1       92.000000          25.000000
# 4       5.000000   299       0       85.510417          18.000000
# ..           ...   ...     ...             ...                ...
# 995  5416.019792   516       1       85.000000          20.000000
# 996  4497.000000    41       0       91.000000          17.630526
# 997  1886.000000   962       1       85.000000           8.000000
# 998  7636.000000   461       1       88.000000          17.000000
# 999  8021.000000   596       0       88.000000          10.000000
#
#      PreviousGrade  ExtracurricularActivities  ParentalSupport  FinalGrade  \
# 0        78.000000                        1.0                0   80.000000
# 1        85.000000                        2.0                2   87.000000
# 2        65.000000                        0.0                1   68.000000
# 3        90.000000                        3.0                0   92.000000
# 4        82.000000                        2.0                2   85.000000
# ..             ...                        ...              ...         ...
# 995      77.598759                        1.0                0   72.000000
# 996      86.000000                        0.0                0   90.000000
# 997      82.000000                        2.0                1   68.000000
# 998      60.000000                        2.0                0   85.000000
# 999      90.000000                        1.0                2   80.030208
#
#      Study Hours  Attendance (%)  Online Classes Taken
# 0            4.8            59.0                     0
# 1            2.2            70.0                     1
# 2            4.6            92.0                     0
# 3            2.9            96.0                     0
# 4            4.1            97.0                     1
# ..           ...             ...                   ...
# 995          0.8            80.0                     1
# 996          3.9            80.0                     1
# 997          0.4            54.0                     0
# 998          0.9            53.0                     1
# 999          2.4            94.0                     1
#
# [1000 rows x 12 columns]
